# %%
import matplotlib.pyplot as plt
from strucpara.analysis import BaseStepAgent
rootfolder = '/home/ytcdata/x3dna_data'

# %% [markdown]
# ### Part 1: Initialize

# %%
time_interval = '0_1us' # '0_1us', '1_2us', '2_3us', '3_4us', '4_5us'
bp_agent = BaseStepAgent(rootfolder, time_interval)

# %% [markdown]
# ### Part 2: Histogram for parameters

# %%
figsize = (12, 4)
bins = 100
sele_para = 'shift' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'tilt' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'slide' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'roll' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'rise' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'twist' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()
