# %%
import matplotlib.pyplot as plt
import numpy as np
from strucpara.analysis import GrooveAgent
rootfolder = '/home/ytcdata/x3dna_data'

# %% [markdown]
# ### Part 1: Initialize

# %%
bp_agent = GrooveAgent(rootfolder)

# %% [markdown]
# ### Part 2: Four systems, 0-5$\mu$s

# %%
figsize = (8, 8)
sele_para = 'major_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
bins = 40
xlines = range(10,31,5) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.05, 0.26, 0.05) # None or [yvalue1, yvalue2, ...]
xlim = None # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'minor_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
bins = 40
xlines = range(10,17,2) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.1,0.51,0.1) # None or [yvalue1, yvalue2, ...]
xlim = (8,18) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 3: Histogram for parameters, Original Six Systems, only 1 $\mu$s

# %%
figsize = (12, 4)
bins = 50
sele_para = 'major_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
xlines = range(12,28,2)
xlim = (12,28)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 50
sele_para = 'minor_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
xlines = range(7,17)
xlim = (7,17.5)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 3: Six Histogram: Major

# %%
figsize = (6, 4)
bins = 50
sele_para = 'major_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'


fig, axes = bp_agent.histogram_six(figsize, sele_para, bins)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 4: Six Histogram: Minor

# %%
figsize = (6, 4)
bins = 50
sele_para = 'minor_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'


fig, axes = bp_agent.histogram_six(figsize, sele_para, bins)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()
