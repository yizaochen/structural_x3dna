# %%
import matplotlib.pyplot as plt
import numpy as np
from strucpara.analysis import BaseStepAgent
rootfolder = '/home/ytcdata/x3dna_data'

# %% [markdown]
# ### Part 1: Initialize

# %%
bp_agent = BaseStepAgent(rootfolder)

# %% [markdown]
# ### Part 2: Four systems, 0-5$\mu$s

# %%
figsize = (8, 8)
sele_para = 'shift' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
bins = 100
xlines = range(-2,3) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.1,0.81,0.1) # None or [yvalue1, yvalue2, ...]
xlim = (-3,3) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'tilt' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
bins = 100
xlines = range(-20,21,10) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.02,0.081,0.02) # None or [yvalue1, yvalue2, ...]
xlim = (-25,25) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'slide' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
bins = 100
xlines = range(-2,3) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.1,0.81,0.1) # None or [yvalue1, yvalue2, ...]
xlim = (-3,3) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'roll' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
bins = 100
xlines = range(-20,21,10) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.01,0.081,0.01) # None or [yvalue1, yvalue2, ...]
xlim = (-30,30) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'rise' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
bins = 100
xlines = np.arange(2.5,4.6,0.5) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.2,1.7,0.2) # None or [yvalue1, yvalue2, ...]
xlim = (2,5) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'twist' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
bins = 100
xlines = range(10,51,10) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.01,0.071,0.01) # None or [yvalue1, yvalue2, ...]
xlim = (0,60) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 3: Histogram for parameters, Original Six Systems, only 1 $\mu$s

# %%
figsize = (12, 4)
bins = 100
sele_para = 'shift' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(-4,5)
xlim = (-4,4)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'tilt' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(-20,25,5)
xlim = (-20,20)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'slide' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(-3,3)
xlim = (-3,2)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'roll' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(-20,35,10)
xlim = (-25,30)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'rise' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = np.arange(2,5,0.5)
xlim = (2,5)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'twist' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(10,60,10)
xlim = (10,60)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 3: Twist bimodal further analysis

# %%
figsize = (12, 8)
bins = 100
sele_para = 'twist' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, ax = bp_agent.histogram_bimodal(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'twist_bimodal.png', dpi=150)
plt.show()
