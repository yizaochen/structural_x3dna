# %%
import matplotlib.pyplot as plt
import numpy as np
from strucpara.analysis import BasePairAgent
rootfolder = '/home/ytcdata/x3dna_data'

# %% [markdown]
# ### Part 1: Initialize

# %%
bp_agent = BasePairAgent(rootfolder)

# %% [markdown]
# ### Part 2: Four systems, 0-5$\mu$s

# %%
figsize = (8, 8)
sele_para = 'shear' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
bins = 100
xlines = range(-3, 3) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.2, 1.41, 0.2) # None or [yvalue1, yvalue2, ...]
xlim = (-3,3) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'buckle' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
bins = 100
xlines = range(-40,81,20) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.01,0.041,0.01) # None or [yvalue1, yvalue2, ...]
xlim = None # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'stretch' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
bins = 100
xlines = np.arange(-0.75,0.76,0.25) # None or [xvalue1, xvalue2, ...]
ylines = range(1,5) # None or [yvalue1, yvalue2, ...]
xlim = (-1,1) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'propeller' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
bins = 100
xlines = range(-60,41,20) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.01,0.051,0.01) # None or [yvalue1, yvalue2, ...]
xlim = None # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'stagger' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
bins = 100
xlines = range(-2,3) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.2,1.1,0.2) # None or [yvalue1, yvalue2, ...]
xlim = (-3,3) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %%
figsize = (8, 8)
sele_para = 'opening' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
bins = 100
xlines = range(-20,21,10) # None or [xvalue1, xvalue2, ...]
ylines = np.arange(0.02,0.13,0.02) # None or [yvalue1, yvalue2, ...]
xlim = (-25, 25) # None or (xmin, xmax)
ylim = None  # None or (ymin, ymax)
xticks = None
yticks = None

fig, axes = bp_agent.histogram_four_sys_one_para(figsize, sele_para, bins, xlines, ylines, xlim, ylim, xticks, yticks)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 3: Histogram for parameters, Original Six Systems, only 1 $\mu$s

# %%
figsize = (12, 4)
bins = 100
sele_para = 'shear' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
xlines = [-1, 0, 1]
xlim = (-2,2)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'stretch' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
xlines = [-0.5, 0, 0.5]
xlim = (-1,1)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'buckle' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
xlines = [-40, -20, 0, 20, 40]
xlim = (-50, 45)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'propeller' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
xlines = [-40,-30,-20,-10, 0, 10, 20]
xlim = (-45,35)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'stagger' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
xlines = [-1, 0, 1]
xlim = (-2, 2)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'opening' #'shear', 'buckle', 'stretch', 'propeller', 'stagger', 'opening'
xlines = []
xlim = (-25,25)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()
